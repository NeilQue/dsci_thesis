# %%
import tensorflow as tf
import pandas as pd
import os
import numpy as np
import datetime as dt
from random import seed
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import backend as K
tf.compat.v1.experimental.output_all_intermediates(True)
import shap
from sklearn.preprocessing import OneHotEncoder

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\jerem\AppData\Local\Programs\Python\Python310\python.exe

# %%
seed(36)

# %%
df = pd.read_csv("2016_2017_sto_nino_and_montalban.csv")
df.head(10)
# Out:
#    Unnamed: 0             datetime  month  day  hour        t    Station
# 0           0  2016-01-01 00:00:00      1    1     0      0.0  Montalban  \
# 1           1  2016-01-01 00:00:00      1    1     0      0.0   Sto_Nino
# 2           2  2016-01-01 01:00:00      1    1     1   3600.0  Montalban
# 3           3  2016-01-01 01:00:00      1    1     1   3600.0   Sto_Nino
# 4           4  2016-01-01 02:00:00      1    1     2   7200.0  Montalban
# 5           5  2016-01-01 02:00:00      1    1     2   7200.0   Sto_Nino
# 6           6  2016-01-01 03:00:00      1    1     3  10800.0  Montalban
# 7           7  2016-01-01 03:00:00      1    1     3  10800.0   Sto_Nino
# 8           8  2016-01-01 04:00:00      1    1     4  14400.0  Montalban
# 9           9  2016-01-01 04:00:00      1    1     4  14400.0   Sto_Nino
#
#        x  Rainfall_Aries  Rainfall_Boso  Rainfall_Campana  Rainfall_Nangka
# 0      0               0              1                 2                0  \
# 1  14420               0              1                 2                0
# 2      0               0              1                 1                1
# 3  14420               0              1                 1                1
# 4      0               1              1                 1                0
# 5  14420               1              1                 1                0
# 6      0               0              0                 0                1
# 7  14420               0              0                 0                1
# 8      0               1              1                 1                0
# 9  14420               1              1                 1                0
#
#    Rainfall_Oro  Waterlevel  Discharge  Cross_Section  Velocity  fric_coeff
# 0             0       21.03  14.842428         630.90  0.023526       0.035  \
# 1             0       12.18  21.033407         803.88  0.026165       0.033
# 2             0       21.03  14.842428         630.90  0.023526       0.035
# 3             0       12.19  21.280072         804.54  0.026450       0.033
# 4             1       21.03  14.842428         630.90  0.023526       0.035
# 5             1       12.19  21.280072         804.54  0.026450       0.033
# 6             0       21.03  14.842428         630.90  0.023526       0.035
# 7             0       12.20  21.529056         805.20  0.026738       0.033
# 8             0       21.03  14.842428         630.90  0.023526       0.035
# 9             0       12.20  21.529056         805.20  0.026738       0.033
#
#       slope
# 0  0.002000
# 1  0.000667
# 2  0.002000
# 3  0.000667
# 4  0.002000
# 5  0.000667
# 6  0.002000
# 7  0.000667
# 8  0.002000
# 9  0.000667

# %%
# Binary Encode the Station
df_encoded = df.copy()
df_encoded['Station'] = df['Station'].map({'Sto_Nino': 1, 'Montalban': 0})

'''
encoder = OneHotEncoder(sparse_output=False)
encoded_data = encoder.fit_transform(df[['Station']])
encoded_df = pd.DataFrame(
    encoded_data,
    columns=encoder.get_feature_names_out(['Station'])
)

df_encoded = pd.concat([df.drop('Station', axis=1), encoded_df], axis=1)
'''
# Out:
# "\nencoder = OneHotEncoder(sparse_output=False)\nencoded_data = encoder.fit_transform(df[['Station']])\nencoded_df = pd.DataFrame(\n    encoded_data,\n    columns=encoder.get_feature_names_out(['Station'])\n)\n\ndf_encoded = pd.concat([df.drop('Station', axis=1), encoded_df], axis=1)\n"

# %%
df_encoded
# Out:
#        Unnamed: 0             datetime  month  day  hour           t  Station
# 0               0  2016-01-01 00:00:00      1    1     0         0.0        0  \
# 1               1  2016-01-01 00:00:00      1    1     0         0.0        1
# 2               2  2016-01-01 01:00:00      1    1     1      3600.0        0
# 3               3  2016-01-01 01:00:00      1    1     1      3600.0        1
# 4               4  2016-01-01 02:00:00      1    1     2      7200.0        0
# ...           ...                  ...    ...  ...   ...         ...      ...
# 35035       35035  2017-12-31 21:00:00     12   31    21  63147600.0        1
# 35036       35036  2017-12-31 22:00:00     12   31    22  63151200.0        0
# 35037       35037  2017-12-31 22:00:00     12   31    22  63151200.0        1
# 35038       35038  2017-12-31 23:00:00     12   31    23  63154800.0        0
# 35039       35039  2017-12-31 23:00:00     12   31    23  63154800.0        1
#
#            x  Rainfall_Aries  Rainfall_Boso  Rainfall_Campana
# 0          0               0              1                 2  \
# 1      14420               0              1                 2
# 2          0               0              1                 1
# 3      14420               0              1                 1
# 4          0               1              1                 1
# ...      ...             ...            ...               ...
# 35035  14420               0              0                 0
# 35036      0               0              0                 0
# 35037  14420               0              0                 0
# 35038      0               0              0                 0
# 35039  14420               0              0                 0
#
#        Rainfall_Nangka  Rainfall_Oro  Waterlevel  Discharge  Cross_Section
# 0                    0             0       21.03  14.842428         630.90  \
# 1                    0             0       12.18  21.033407         803.88
# 2                    1             0       21.03  14.842428         630.90
# 3                    1             0       12.19  21.280072         804.54
# 4                    0             1       21.03  14.842428         630.90
# ...                ...           ...         ...        ...            ...
# 35035                0             0       12.44  28.244204         821.04
# 35036                0             0       21.18  17.224575         635.40
# 35037                0             0       12.44  28.244204         821.04
# 35038                0             0       21.18  17.224575         635.40
# 35039                0             0       12.44  28.244204         821.04
#
#        Velocity  fric_coeff     slope
# 0      0.023526       0.035  0.002000
# 1      0.026165       0.033  0.000667
# 2      0.023526       0.035  0.002000
# 3      0.026450       0.033  0.000667
# 4      0.023526       0.035  0.002000
# ...         ...         ...       ...
# 35035  0.034401       0.033  0.000667
# 35036  0.027108       0.035  0.002000
# 35037  0.034401       0.033  0.000667
# 35038  0.027108       0.035  0.002000
# 35039  0.034401       0.033  0.000667
#
# [35040 rows x 19 columns]

# %%
n = len(df)

# %%
test = df[int(n*0.75):]
test_dates = test['datetime']
test_dates
# Out:
# 26280    2017-07-02 12:00:00
# 26281    2017-07-02 12:00:00
# 26282    2017-07-02 13:00:00
# 26283    2017-07-02 13:00:00
# 26284    2017-07-02 14:00:00
#                 ...
# 35035    2017-12-31 21:00:00
# 35036    2017-12-31 22:00:00
# 35037    2017-12-31 22:00:00
# 35038    2017-12-31 23:00:00
# 35039    2017-12-31 23:00:00
# Name: datetime, Length: 8760, dtype: object

# %%
test_dates = pd.to_datetime(test_dates)

# %%
montalban_df = df_encoded[df_encoded["Station"] == 0]
stonino_df = df_encoded[df_encoded["Station"] == 1]

# %%
montalban_df
# Out:
#        Unnamed: 0             datetime  month  day  hour           t  Station
# 0               0  2016-01-01 00:00:00      1    1     0         0.0        0  \
# 2               2  2016-01-01 01:00:00      1    1     1      3600.0        0
# 4               4  2016-01-01 02:00:00      1    1     2      7200.0        0
# 6               6  2016-01-01 03:00:00      1    1     3     10800.0        0
# 8               8  2016-01-01 04:00:00      1    1     4     14400.0        0
# ...           ...                  ...    ...  ...   ...         ...      ...
# 35030       35030  2017-12-31 19:00:00     12   31    19  63140400.0        0
# 35032       35032  2017-12-31 20:00:00     12   31    20  63144000.0        0
# 35034       35034  2017-12-31 21:00:00     12   31    21  63147600.0        0
# 35036       35036  2017-12-31 22:00:00     12   31    22  63151200.0        0
# 35038       35038  2017-12-31 23:00:00     12   31    23  63154800.0        0
#
#        x  Rainfall_Aries  Rainfall_Boso  Rainfall_Campana  Rainfall_Nangka
# 0      0               0              1                 2                0  \
# 2      0               0              1                 1                1
# 4      0               1              1                 1                0
# 6      0               0              0                 0                1
# 8      0               1              1                 1                0
# ...   ..             ...            ...               ...              ...
# 35030  0               0              0                 0                0
# 35032  0               0              0                 0                0
# 35034  0               0              0                 0                0
# 35036  0               0              0                 0                0
# 35038  0               0              0                 0                0
#
#        Rainfall_Oro  Waterlevel  Discharge  Cross_Section  Velocity
# 0                 0       21.03  14.842428          630.9  0.023526  \
# 2                 0       21.03  14.842428          630.9  0.023526
# 4                 1       21.03  14.842428          630.9  0.023526
# 6                 0       21.03  14.842428          630.9  0.023526
# 8                 0       21.03  14.842428          630.9  0.023526
# ...             ...         ...        ...            ...       ...
# 35030             0       21.18  17.224575          635.4  0.027108
# 35032             0       21.18  17.224575          635.4  0.027108
# 35034             0       21.18  17.224575          635.4  0.027108
# 35036             0       21.18  17.224575          635.4  0.027108
# 35038             0       21.18  17.224575          635.4  0.027108
#
#        fric_coeff  slope
# 0           0.035  0.002
# 2           0.035  0.002
# 4           0.035  0.002
# 6           0.035  0.002
# 8           0.035  0.002
# ...           ...    ...
# 35030       0.035  0.002
# 35032       0.035  0.002
# 35034       0.035  0.002
# 35036       0.035  0.002
# 35038       0.035  0.002
#
# [17520 rows x 19 columns]

# %%
df_encoded_1 = df_encoded[['month', 'day', 'hour', 'Station', 'Rainfall_Aries', 'Rainfall_Boso', 'Rainfall_Campana', 'Rainfall_Nangka', 'Rainfall_Oro', 'Waterlevel']]

# Splitting for time series: split into 50-25-25
n = len(df_encoded_1)
train_df_combined = df_encoded_1[0:int(n*0.5)]
val_df_combined = df_encoded_1[int(n*0.5):int(n*0.75)]
test_df_combined = df_encoded_1[int(n*0.75):]

# %%
montalban_df_1 = montalban_df[['month', 'day', 'hour', 'Rainfall_Aries', 'Rainfall_Boso', 'Rainfall_Campana', 'Rainfall_Nangka', 'Rainfall_Oro', 'Waterlevel']]
sto_nino_df_1 = stonino_df[['month', 'day', 'hour', 'Rainfall_Aries', 'Rainfall_Boso', 'Rainfall_Campana', 'Rainfall_Nangka', 'Rainfall_Oro', 'Waterlevel']]

# %%
#sto_nino_df_1 = sto_nino_df_1.drop(columns='Station')
#montalban_df_1 = montalban_df_1.drop(columns = 'Station')

# %%
montalban_df_1
# Out:
#        month  day  hour  Rainfall_Aries  Rainfall_Boso  Rainfall_Campana
# 0          1    1     0               0              1                 2  \
# 2          1    1     1               0              1                 1
# 4          1    1     2               1              1                 1
# 6          1    1     3               0              0                 0
# 8          1    1     4               1              1                 1
# ...      ...  ...   ...             ...            ...               ...
# 35030     12   31    19               0              0                 0
# 35032     12   31    20               0              0                 0
# 35034     12   31    21               0              0                 0
# 35036     12   31    22               0              0                 0
# 35038     12   31    23               0              0                 0
#
#        Rainfall_Nangka  Rainfall_Oro  Waterlevel
# 0                    0             0       21.03
# 2                    1             0       21.03
# 4                    0             1       21.03
# 6                    1             0       21.03
# 8                    0             0       21.03
# ...                ...           ...         ...
# 35030                0             0       21.18
# 35032                0             0       21.18
# 35034                0             0       21.18
# 35036                0             0       21.18
# 35038                0             0       21.18
#
# [17520 rows x 9 columns]

# %% [markdown]
# ## Sto. Nino Model

# %%
# Splitting for time series: split into 50-25-25
n = len(sto_nino_df_1)
train_df_sto_nino = sto_nino_df_1[0:int(n*0.5)]
val_df_sto_nino = sto_nino_df_1[int(n*0.5):int(n*0.75)]
test_df_sto_nino = sto_nino_df_1[int(n*0.75):]

# %%
n = len(montalban_df_1)
train_df_montalban = montalban_df_1[0:int(n*0.5)]
val_df_montalban = montalban_df_1[int(n*0.5):int(n*0.75)]
test_df_montalban = montalban_df_1[int(n*0.75):]

# %%
class WindowGenerator():
    def __init__(self, input_width, label_width, shift, train_df, val_df, test_df, label_columns=None):
        # Store the raw data.
        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df

        # Work out the label column indices.
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}

        # Work out the window parameters.
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift

        self.total_window_size = input_width + shift

        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]

        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]

    def __repr__(self):
        return '\n'.join([
            f'Total window size: {self.total_window_size}',
            f'Input indices: {self.input_indices}',
            f'Label indices: {self.label_indices}',
            f'Label column name(s): {self.label_columns}'])

    def split_window(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack([labels[:, :, self.column_indices[name]] for name in self.label_columns], axis=-1)

        # Slicing doesn't preserve static shape information, so set the shapes
        # manually. This way the `tf.data.Datasets` are easier to inspect.
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])

        return inputs, labels
    
    # Creating tf datasets for more convenient use and integration into model in the future
    def make_dataset(self, data, shuffle = True):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.utils.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=1,
            shuffle=shuffle,
            batch_size=32,)

        ds = ds.map(self.split_window)

        return ds
    
    # properties to access them as tf datasets
    @property
    def train(self):
        return self.make_dataset(self.train_df)

    @property
    def val(self):
        return self.make_dataset(self.val_df)

    @property
    def test(self):
        return self.make_dataset(self.test_df, False)

    @property
    def example(self):
        """Get and cache an example batch of `inputs, labels` for plotting."""
        result = getattr(self, '_example', None)
        if result is None:
            # No example batch was found, so get one from the `.train` dataset
            result = next(iter(self.train))
            # And cache it for next time
            self._example = result
        return result

# %%
CONSECUTIVE_HOURS = 1
window_sto_nino = WindowGenerator(
        input_width=CONSECUTIVE_HOURS, label_width=1, shift=1,
        train_df=train_df_sto_nino, 
        val_df=val_df_sto_nino,
        test_df=test_df_sto_nino,
        label_columns=['Waterlevel']
    )

window_sto_nino
# Out:
# Total window size: 2
# Input indices: [0]
# Label indices: [1]
# Label column name(s): ['Waterlevel']

# %%
window_montalban = WindowGenerator(
        input_width=CONSECUTIVE_HOURS, label_width=1, shift=1,
        train_df=train_df_montalban, 
        val_df=val_df_montalban,
        test_df=test_df_montalban,
        label_columns=['Waterlevel']
    )

window_montalban
# Out:
# Total window size: 2
# Input indices: [0]
# Label indices: [1]
# Label column name(s): ['Waterlevel']

# %%
window_combined = WindowGenerator(
        input_width=CONSECUTIVE_HOURS, label_width=1, shift=1,
        train_df=train_df_combined, 
        val_df=val_df_combined,
        test_df=test_df_combined,
        label_columns=['Waterlevel']
    )

window_combined
# Out:
# Total window size: 2
# Input indices: [0]
# Label indices: [1]
# Label column name(s): ['Waterlevel']

# %%
def r_square(y_true, y_pred):
    x = y_true
    y = y_pred
    mx = K.mean(x, axis=0)
    my = K.mean(y, axis=0)
    xm, ym = x - mx, y - my
    r_num = K.square(K.sum(xm * ym))
    x_square_sum = K.sum(xm * xm)
    y_square_sum = K.sum(ym * ym)
    r_den = (x_square_sum * y_square_sum) + K.epsilon()
    
    r = r_num / r_den
    return r

# %%
def NSE(y_true, y_pred):
    '''
    This is the Nash-Sutcliffe Efficiency Coefficient
    '''
    y_pred = K.flatten(y_pred)
    y_true = K.flatten(y_true)

    
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true))) 
    
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
# For easy compiling and fitting of different models
MAX_EPOCHS = 20

def compile_and_fit(model, window, patience=2):
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience, mode='min')

    model.compile(
        loss=tf.keras.losses.MeanSquaredError(), 
        optimizer='adam', 
        metrics=[tf.keras.metrics.MeanSquaredError(), NSE, r_square]
    )

    history = model.fit(
        window.train, 
        epochs=MAX_EPOCHS,
        validation_data=window.val,
        callbacks=[early_stopping]
    )

    return history

# %%
# LSTM
lstm_model_sto_nino = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(64, return_sequences=True),
    tf.keras.layers.Dense(units=64, activation='relu'),
    tf.keras.layers.Dense(units=64, activation='relu'),
    tf.keras.layers.Dense(units=1)
])

lstm_model_montalban = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(64, return_sequences=True),
    tf.keras.layers.Dense(units=64, activation='relu'),
    tf.keras.layers.Dense(units=64, activation='relu'),
    tf.keras.layers.Dense(units=1)
])

# %%
lstm_history_sto_nino = compile_and_fit(lstm_model_sto_nino, window_sto_nino)
# Out:
# Epoch 1/20
# 274/274 [==============================] - 4s 8ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - NSE: 0.9435 - r_square: 0.9819 - val_loss: 0.0183 - val_mean_squared_error: 0.0183 - val_NSE: 0.7031 - val_r_square: 0.8565
# Epoch 2/20
# 274/274 [==============================] - 2s 6ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - NSE: 0.9769 - r_square: 0.9835 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - val_NSE: 0.6725 - val_r_square: 0.8380
# Epoch 3/20
# 274/274 [==============================] - 2s 6ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - NSE: 0.9694 - r_square: 0.9808 - val_loss: 0.0151 - val_mean_squared_error: 0.0151 - val_NSE: 0.7859 - val_r_square: 0.8839
# Epoch 4/20
# 274/274 [==============================] - 2s 6ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - NSE: 0.9721 - r_square: 0.9824 - val_loss: 0.0208 - val_mean_squared_error: 0.0208 - val_NSE: 0.7084 - val_r_square: 0.8257
# Epoch 5/20
# 274/274 [==============================] - 2s 6ms/step - loss: 0.0104 - mean_squared_error: 0.0104 - NSE: 0.9716 - r_square: 0.9840 - val_loss: 0.0191 - val_mean_squared_error: 0.0191 - val_NSE: 0.7206 - val_r_square: 0.8639

# %%
lstm_history_montalban = compile_and_fit(lstm_model_montalban, window_montalban)
# Out:
# Epoch 1/20
# 274/274 [==============================] - 5s 8ms/step - loss: 52.8087 - mean_squared_error: 52.8087 - NSE: -149.3918 - r_square: 0.2571 - val_loss: 0.2187 - val_mean_squared_error: 0.2187 - val_NSE: -22.4225 - val_r_square: 0.1124
# Epoch 2/20
# 274/274 [==============================] - 2s 5ms/step - loss: 0.3217 - mean_squared_error: 0.3217 - NSE: 0.3526 - r_square: 0.4560 - val_loss: 0.1562 - val_mean_squared_error: 0.1562 - val_NSE: -16.3647 - val_r_square: 0.0972
# Epoch 3/20
# 274/274 [==============================] - 2s 6ms/step - loss: 0.2868 - mean_squared_error: 0.2868 - NSE: 0.4345 - r_square: 0.5179 - val_loss: 0.1268 - val_mean_squared_error: 0.1268 - val_NSE: -12.9213 - val_r_square: 0.0994
# Epoch 4/20
# 274/274 [==============================] - 1s 5ms/step - loss: 0.2665 - mean_squared_error: 0.2665 - NSE: 0.4868 - r_square: 0.5539 - val_loss: 0.1480 - val_mean_squared_error: 0.1480 - val_NSE: -15.1226 - val_r_square: 0.0672
# Epoch 5/20
# 274/274 [==============================] - 1s 5ms/step - loss: 0.2507 - mean_squared_error: 0.2507 - NSE: 0.5152 - r_square: 0.5923 - val_loss: 0.1280 - val_mean_squared_error: 0.1280 - val_NSE: -12.2291 - val_r_square: 0.0796

# %% [markdown]
# ## Evaluating on the Test Set

# %%
performance = {}

# %%
performance['Sto_Nino_LSTM'] = lstm_model_sto_nino.evaluate(window_sto_nino.test)
# Out:
# 137/137 [==============================] - 1s 3ms/step - loss: 0.0246 - mean_squared_error: 0.0246 - NSE: -44515.7070 - r_square: 0.4659

# %%
performance['Montalban_LSTM'] = lstm_model_montalban.evaluate(window_montalban.test)
# Out:
# 137/137 [==============================] - 1s 3ms/step - loss: 0.2992 - mean_squared_error: 0.2992 - NSE: -4312233.0000 - r_square: 0.0870

# %%
performance
# Out:
# {'Sto_Nino_LSTM': [0.01972351409494877,
#   0.01972351409494877,
#   -19018.099609375,
#   0.4636204242706299],
#  'Montalban_LSTM': [0.2991552948951721,
#   0.2991552948951721,
#   -4312233.0,
#   0.08697040379047394]}

# %%
import pandas as pd
df_perf = pd.DataFrame.from_dict(performance, orient='index', columns=['Loss', 'MSE', 'NSE', 'R^2'])

# %%
df_perf
# Out:
#                     Loss       MSE           NSE      R^2
# Sto_Nino_LSTM   0.028645  0.028645 -1.129540e+05  0.41160
# Montalban_LSTM  0.299155  0.299155 -4.312233e+06  0.08697

# %% [markdown]
# ## SHAP Feature Selection (Sto. Nino)

# %%
import shap
import numpy as np

# Extract a batch of test data
test_data = []
for inputs, _ in window_sto_nino.test.take(1):
    test_data = inputs.numpy()
    break

# Create a flattened version for the explainer
test_data_flat = test_data.reshape(test_data.shape[0], -1)  # Flatten time steps and features

# Create a prediction function that returns a single value (e.g., last time step of water level)
def predict_last_step(X):
    # Reshape back to 3D
    batch_size = X.shape[0]
    time_steps = window_sto_nino.input_width
    features = len(window_sto_nino.train_df.columns)
    
    X_reshaped = X.reshape(batch_size, time_steps, features)
    
    # Get model predictions
    preds = lstm_model_sto_nino.predict(X_reshaped)
    
    # Return the last time step prediction for water level
    return preds[:, -1, 0]  # Last time step, first feature (water level)

# Select a smaller subset for background data
background_data_flat = test_data_flat[:50]  # Using 50 samples as background

# Create the explainer
explainer = shap.KernelExplainer(predict_last_step, background_data_flat)

# Calculate SHAP values for a few test samples
shap_values = explainer.shap_values(test_data_flat[:10])  # Explain 10 samples

# Reshape the SHAP values back to the original input format
shap_values_reshaped = shap_values.reshape(10, window_sto_nino.input_width, -1)

# Create a feature importance plot
feature_names = list(window_sto_nino.train_df.columns)
shap_importance = np.abs(shap_values).mean(axis=0)
feature_importance = []

# Reshape the importance values to match features
for i in range(len(feature_names)):
    start_idx = i
    end_idx = len(feature_names) * window_sto_nino.input_width
    step = len(feature_names)
    feature_importance.append(np.mean(shap_importance[start_idx:end_idx:step]))

# Plot feature importance
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(feature_names, feature_importance)
plt.title('Feature Importance for Water Level Prediction')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 497ms/step
#   0%|          | 0/10 [00:00<?, ?it/s]
# 1/1 [==============================] - 1s 510ms/step
# 254/254 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 254/254 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 20ms/step
# 254/254 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 10ms/step
# 254/254 [==============================] - 1s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 254/254 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 19ms/step
# 254/254 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 9ms/step
# 254/254 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 254/254 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 20ms/step
# 254/254 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 254/254 [==============================] - 0s 1ms/step

# %%
shap_importance
# Out:
# array([0.        , 0.00846873, 0.02874112, 0.05691051, 0.04874481,
#        0.01126164, 0.00878898, 0.02765094, 0.32313027])

# %%
feature_importance
# Out:
# [0.0,
#  0.008468729999093766,
#  0.02874112068542411,
#  0.056910511989678655,
#  0.04874480789261203,
#  0.01126163515661446,
#  0.008788979596325332,
#  0.02765094177708739,
#  0.32313026660609795]

# %%
def get_predictions(model, test_set):
    y_pred = []
    
    for x, _ in test_set:
        predictions = model(x)
        for y in predictions:
            y_pred.append(y)
    
    y_pred = np.array(y_pred)
    y_pred = y_pred.reshape(-1)
    
    return y_pred

# %%
y_true = test_df_sto_nino['Waterlevel']
y_true = y_true.values
y_true = y_true[CONSECUTIVE_HOURS:]
y_true
# Out:
# array([11.87, 11.85, 11.84, ..., 12.44, 12.44, 12.44])

# %%
get_predictions(lstm_model_sto_nino, window_sto_nino.test)
# Out:
# array([11.870762, 11.86363 , 11.858746, ..., 12.306507, 12.302643,
#        12.296849], dtype=float32)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'shap_values' contains your calculated SHAP values
# and 'feature_names' contains your feature names

# Get the index of the 'Waterlevel' feature to exclude it
waterlevel_index = feature_names.index('Waterlevel')

# Create a mask to filter out the Waterlevel feature
mask = np.ones(len(feature_names), dtype=bool)
mask[waterlevel_index] = False

# Filter feature names and importance values
filtered_feature_names = [feature_names[i] for i in range(len(feature_names)) if i != waterlevel_index]

# For the flat KernelExplainer approach:
filtered_feature_importance = []
for i in range(len(feature_names)):
    if i != waterlevel_index:
        start_idx = i
        end_idx = len(feature_names) * window_sto_nino.input_width
        step = len(feature_names)
        filtered_feature_importance.append(np.mean(shap_importance[start_idx:end_idx:step]))

# Sort features by importance
sorted_indices = np.argsort(filtered_feature_importance)[::-1]  # Descending order
sorted_feature_names = [filtered_feature_names[i] for i in sorted_indices]
sorted_importance = [filtered_feature_importance[i] for i in sorted_indices]

# Create the bar chart
plt.figure(figsize=(12, 8))
bars = plt.bar(sorted_feature_names, sorted_importance, color='skyblue')
plt.title('Sto. Nino Water Level Feature Importance (Excluding Previous Water Level)', fontsize=16)
plt.xlabel('Features', fontsize=14)
plt.ylabel('Average |SHAP Value|', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.tight_layout()


# Add grid lines for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
# Create a pie chart with improved label placement
plt.figure(figsize=(12, 12))  # Slightly larger figure

# Create pie with smaller wedges to make room for labels
wedges, texts, autotexts = plt.pie(
    sorted_importance, 
    labels=None,  # Remove default labels
    autopct='%1.1f%%',
    startangle=90, 
    shadow=True, 
    explode=[0.1]*len(sorted_importance),  # Increase explosion to separate wedges more
    textprops={'fontsize': 12}
)

# Enhance the appearance of percentage labels inside the pie
for autotext in autotexts:
    autotext.set_color('white')
    autotext.set_fontweight('bold')

# Add legend outside the pie chart instead of direct labels
plt.legend(
    wedges, 
    sorted_feature_names,
    title="Features",
    loc="center left",
    bbox_to_anchor=(1, 0, 0.5, 1)  # Position legend to the right of the pie
)

plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.title('Sto. Nino Water Level Relative Feature Importance (Excluding Water Level)', fontsize=16)
plt.tight_layout()
plt.show()

# %%
sorted_feature_names
# Out:
# ['Rainfall_Aries',
#  'Rainfall_Boso',
#  'hour',
#  'Rainfall_Oro',
#  'Rainfall_Campana',
#  'Rainfall_Nangka',
#  'day',
#  'month']

# %%
sorted_importance
# Out:
# [0.056910511989678655,
#  0.04874480789261203,
#  0.02874112068542411,
#  0.02765094177708739,
#  0.01126163515661446,
#  0.008788979596325332,
#  0.008468729999093766,
#  0.0]

# %% [markdown]
# ## SHAP Feature Selection (Montalban)

# %%
import shap
import numpy as np

# Extract a batch of test data
test_data = []
for inputs, _ in window_montalban.test.take(1):
    test_data = inputs.numpy()
    break

# Create a flattened version for the explainer
test_data_flat = test_data.reshape(test_data.shape[0], -1)  # Flatten time steps and features

# Create a prediction function that returns a single value (e.g., last time step of water level)
def predict_last_step(X):
    # Reshape back to 3D
    batch_size = X.shape[0]
    time_steps = window_montalban.input_width
    features = len(window_montalban.train_df.columns)
    
    X_reshaped = X.reshape(batch_size, time_steps, features)
    
    # Get model predictions
    preds = lstm_model_montalban.predict(X_reshaped)
    
    # Return the last time step prediction for water level
    return preds[:, -1, 0]  # Last time step, first feature (water level)

# Select a smaller subset for background data
background_data_flat = test_data_flat[:50]  # Using 50 samples as background

# Create the explainer
explainer = shap.KernelExplainer(predict_last_step, background_data_flat)

# Calculate SHAP values for a few test samples
shap_values = explainer.shap_values(test_data_flat[:10])  # Explain 10 samples

# Reshape the SHAP values back to the original input format
shap_values_reshaped = shap_values.reshape(10, window_montalban.input_width, -1)

# Create a feature importance plot
feature_names = list(window_montalban.train_df.columns)
shap_importance = np.abs(shap_values).mean(axis=0)
feature_importance = []

# Reshape the importance values to match features
for i in range(len(feature_names)):
    start_idx = i
    end_idx = len(feature_names) * window_montalban.input_width
    step = len(feature_names)
    feature_importance.append(np.mean(shap_importance[start_idx:end_idx:step]))

# Plot feature importance
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(feature_names, feature_importance)
plt.title('Montalban Water Level Feature Importance for Water Level Prediction')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 483ms/step
#   0%|          | 0/10 [00:00<?, ?it/s]
# 1/1 [==============================] - 1s 687ms/step
# 254/254 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 30ms/step
# 254/254 [==============================] - 1s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 254/254 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 254/254 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 26ms/step
# 254/254 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 43ms/step
# 254/254 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 11ms/step
# 254/254 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 254/254 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 254/254 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 38ms/step
# 254/254 [==============================] - 0s 1ms/step

# %%
shap_importance
# Out:
# array([0.        , 0.02209227, 0.07505733, 0.04754776, 0.15106895,
#        0.03822216, 0.12287131, 0.06851195, 0.01627246])

# %%
feature_importance
# Out:
# [0.0,
#  0.022092269168419096,
#  0.07505732561049812,
#  0.04754776117955741,
#  0.1510689535655942,
#  0.038222158443765544,
#  0.12287131137182913,
#  0.06851195269295954,
#  0.0162724614569119]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'shap_values' contains your calculated SHAP values
# and 'feature_names' contains your feature names

# Get the index of the 'Waterlevel' feature to exclude it
waterlevel_index = feature_names.index('Waterlevel')

# Create a mask to filter out the Waterlevel feature
mask = np.ones(len(feature_names), dtype=bool)
mask[waterlevel_index] = False

# Filter feature names and importance values
filtered_feature_names = [feature_names[i] for i in range(len(feature_names)) if i != waterlevel_index]

# For the flat KernelExplainer approach:
filtered_feature_importance = []
for i in range(len(feature_names)):
    if i != waterlevel_index:
        start_idx = i
        end_idx = len(feature_names) * window_montalban.input_width
        step = len(feature_names)
        filtered_feature_importance.append(np.mean(shap_importance[start_idx:end_idx:step]))

# Sort features by importance
sorted_indices = np.argsort(filtered_feature_importance)[::-1]  # Descending order
sorted_feature_names = [filtered_feature_names[i] for i in sorted_indices]
sorted_importance = [filtered_feature_importance[i] for i in sorted_indices]

# Create the bar chart
plt.figure(figsize=(12, 8))
bars = plt.bar(sorted_feature_names, sorted_importance, color='skyblue')
plt.title('Montalban Water Level Feature Importance (Excluding Water Level)', fontsize=16)
plt.xlabel('Features', fontsize=14)
plt.ylabel('Average |SHAP Value|', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.tight_layout()


# Add grid lines for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
# Create a pie chart with improved label placement
plt.figure(figsize=(12, 12))  # Slightly larger figure

# Create pie with smaller wedges to make room for labels
wedges, texts, autotexts = plt.pie(
    sorted_importance, 
    labels=None,  # Remove default labels
    autopct='%1.1f%%',
    startangle=90, 
    shadow=True, 
    explode=[0.1]*len(sorted_importance),  # Increase explosion to separate wedges more
    textprops={'fontsize': 12}
)

# Enhance the appearance of percentage labels inside the pie
for autotext in autotexts:
    autotext.set_color('white')
    autotext.set_fontweight('bold')

# Add legend outside the pie chart instead of direct labels
plt.legend(
    wedges, 
    sorted_feature_names,
    title="Features",
    loc="center left",
    bbox_to_anchor=(1, 0, 0.5, 1)  # Position legend to the right of the pie
)

plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.title('Montalban Water Level Relative Feature Importance (Excluding Water Level)', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Ensemble Model

# %%
lstm_model_sto_nino
lstm_model_montalban

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.models import Model, clone_model

def create_lstm_ensemble_with_averaged_weights(model1, model2):
    """
    Create an ensemble LSTM model by averaging the weights of two pre-trained LSTM models.
    
    Args:
        model1: First pre-trained LSTM model
        model2: Second pre-trained LSTM model
        
    Returns:
        A new LSTM model with averaged weights
    """
    # Verify that the models have the same architecture
    if len(model1.layers) != len(model2.layers):
        raise ValueError("Models have different architectures (different number of layers)")
    
    # Clone one of the models to create the ensemble model structure
    ensemble_model = clone_model(model1)
    
    # Set the weights of the ensemble model as the average of the two models
    for i, (layer1, layer2) in enumerate(zip(model1.layers, ensemble_model.layers)):
        if len(layer1.weights) > 0:  # Skip layers without weights
            # Get weights from original models
            weights1 = layer1.get_weights()
            weights2 = model2.layers[i].get_weights()
            
            # Verify that the weight shapes match
            if [w.shape for w in weights1] != [w.shape for w in weights2]:
                raise ValueError(f"Weight shapes in layer {i} don't match between models")
            
            # Compute average weights
            avg_weights = []
            for w1, w2 in zip(weights1, weights2):
                avg_weights.append((w1 + w2) / 2.0)
            
            # Set the averaged weights to the ensemble model
            layer2.set_weights(avg_weights)
    
    
    
    return ensemble_model

# Example usage
# Assuming lstm_model_1 and lstm_model_2 are your pre-trained LSTM models
# ensemble_lstm = create_lstm_ensemble_with_averaged_weights(lstm_model_1, lstm_model_2)

# To evaluate the ensemble model
# ensemble_lstm.evaluate(test_data, test_labels)

# To make predictions with the ensemble model
# predictions = ensemble_lstm.predict(new_data)

# %%
ensemble_lstm = create_lstm_ensemble_with_averaged_weights(lstm_model_sto_nino, lstm_model_montalban)

# %%
ensemble_lstm.layers
# Out:
# [<keras.layers.rnn.lstm.LSTM at 0x2a20066a620>,
#  <keras.layers.core.dense.Dense at 0x2a200a9b850>,
#  <keras.layers.core.dense.Dense at 0x2a200a99300>,
#  <keras.layers.core.dense.Dense at 0x2a200abe890>]

# %%
ensemble_lstm.compile(
        loss=tf.keras.losses.MeanSquaredError(), 
        optimizer='adam', 
        metrics=[tf.keras.metrics.MeanSquaredError(), NSE, r_square]
    )

# %%
# Evaluate on the Sto.Nino test df
ensemble_lstm.evaluate(window_sto_nino.test, verbose=0)
# Out:
# [87.1346664428711, 87.1346664428711, -913844096.0, 0.12916173040866852]

# %%
# Evaluate on the Montalban test df
window_montalban.test
ensemble_lstm.evaluate(window_montalban.test, verbose=0)
# Out:
# [310.1130676269531, 310.1130676269531, -16072775680.0, 0.1309027522802353]
